# %%
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

import pandas as pd
from scipy.spatial import distance

# %%
# I need to extract the embeddings for these words
words = ['cat','dog','frog']

embeddings_dict = {}
#glove = open("data/glove.42B.300d.txt", 'r', encoding="utf-8")
#glove.close()

# %%
# !head data/glove.42B.300d.txt

glove = pd.read_csv("data/glove.6B.50d.txt", delimiter=' ', header=None, quoting=3)

# %%
glove.describe()
# Out:
#                   1              2              3              4   \
# count  400000.000000  400000.000000  400000.000000  400000.000000
# mean       -0.129201      -0.288662      -0.012249      -0.056767
# std         0.636704       0.613996       0.612466       0.624203
# min        -5.459300      -3.630000      -3.883500      -4.625200
# 25%        -0.534942      -0.683262      -0.407460      -0.463890
# 50%        -0.133555      -0.315320      -0.009604      -0.082614
# 75%         0.274583       0.079589       0.386820       0.325983
# max         3.874000       4.018300       3.977500       5.310100
#
#                   5              6              7              8   \
# count  400000.000000  400000.000000  400000.000000  400000.000000
# mean       -0.202111      -0.083890       0.333597       0.160451
# std         0.639919       0.665588       0.623440       0.608380
# min        -4.054900      -5.309800      -3.427100      -3.934900
# ...

# %%
glove.head()
# Out:
#     0         1         2        3        4        5         6        7   \
# 0  the  0.418000  0.249680 -0.41242  0.12170  0.34527 -0.044457 -0.49688
# 1    ,  0.013441  0.236820 -0.16899  0.40951  0.63812  0.477090 -0.42852
# 2    .  0.151640  0.301770 -0.16763  0.17684  0.31719  0.339730 -0.43478
# 3   of  0.708530  0.570880 -0.47160  0.18048  0.54449  0.726030  0.18157
# 4   to  0.680470 -0.039263  0.30186 -0.17792  0.42962  0.032246 -0.41376
#
#         8        9   ...        41        42        43        44       45  \
# 0 -0.17862 -0.00066  ... -0.298710 -0.157490 -0.347580 -0.045637 -0.44251
# 1 -0.55641 -0.36400  ... -0.080262  0.630030  0.321110 -0.467650  0.22786
# 2 -0.31086 -0.44999  ... -0.000064  0.068987  0.087939 -0.102850 -0.13931
# 3 -0.52393  0.10381  ... -0.347270  0.284830  0.075693 -0.062178 -0.38988
# 4  0.13228 -0.29847  ... -0.094375  0.018324  0.210480 -0.030880 -0.19722
#
#          46        47        48        49       50
# ...

# %%
glove[ glove[0] == 'cat' ]
# Out:
#        0        1        2        3         4        5        6        7   \
# 5450  cat  0.45281 -0.50108 -0.53714 -0.015697  0.22191  0.54602 -0.67301
#
#           8        9   ...        41       42       43       44       45  \
# 5450 -0.6891  0.63493  ... -0.097479  0.48138 -0.43352  0.69455  0.91043
#
#            46       47      48       49       50
# 5450 -0.28173  0.41637 -1.2609  0.71278  0.23782
#
# [1 rows x 51 columns]

# %%
cat = glove[ glove[0] == 'cat' ]
dog = glove[ glove[0] == 'dog' ]
frog = glove[ glove[0] == 'frog' ]

# %%
cat,dog,frog
# Out:
# (       0        1        2        3         4        5        6        7   \
#  5450  cat  0.45281 -0.50108 -0.53714 -0.015697  0.22191  0.54602 -0.67301
#
#            8        9   ...        41       42       43       44       45  \
#  5450 -0.6891  0.63493  ... -0.097479  0.48138 -0.43352  0.69455  0.91043
#
#             46       47      48       49       50
#  5450 -0.28173  0.41637 -1.2609  0.71278  0.23782
#
#  [1 rows x 51 columns],
#         0        1        2        3        4        5        6       7   \
#  2926  dog  0.11008 -0.38781 -0.57615 -0.27714  0.70521  0.53994 -1.0786
#
#             8       9   ...        41       42       43       44      45  \
#  2926 -0.40146  1.1504  ... -0.086199  0.24068 -0.64819  0.83549  1.2502
#
#             46       47       48      49       50
#  2926 -0.51379  0.04224 -0.88118  0.7158  0.38519
#
#  [1 rows x 51 columns],
#           0        1        2        3        4        5        6       7   \
# ...

# %%
catv = np.array( cat.values[0][1:] )
dogv = np.array( dog.values[0][1:] )
frogv = np.array( frog.values[0][1:] )

# %%
distance.euclidean(catv,dogv)
# Out:
# 1.8846031066726727

# %%
def getv(name):
    word = glove[glove[0]==name]
    return np.array( word.values[0][1:] )

# %%
tadpolev = getv('tadpole')
toadv = getv('toad')

# %%
distance.euclidean(frogv,tadpolev)
# Out:
# 4.37459699754767

# %%
distance.euclidean(toadv,frogv)
# Out:
# 3.0397537609993277

# %%
bigv = getv('big')
largev = getv('large')

# %%
distance.euclidean(bigv,largev)
# Out:
# 4.216144564787479

# %%
#Works if I have an embeddings_dict
#def find_closest_embeddings(embedding):
#    return sorted(embeddings_dict.keys(), key=lambda word: spatial.distance.euclidean(embeddings_dict[word], embedding))
